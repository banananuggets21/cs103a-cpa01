# %%
import csv
from matplotlib import pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# 1. The dataset contains information about more than 16,000 different console video games ranging from the 1980s to 2016.
# 2. https://www.kaggle.com/sidtwr/videogames-sales-dataset, then click the download button on the top right. A Kaggle account is required for download. The data needs to be reorganized by date in Excel before it can be processed by the below code.

# %%
# Describe the dataframe
df = pd.read_csv('/Users/jeremybernstein/Downloads/archive/Video_Games_Sales_as_at_22_Dec_2016.csv') #change when moving to git repository!!!!!!

# %%
df.shape
# Out:
# (16719, 16)

# %%
df2 = df[df['Publisher']=='Nintendo']  # select out just those rows with iso_code = USA
df3 = df[df['Publisher']=='Sega']  # select out just those rows with iso_code = USA
df2['Global_Sales'].plot()
df3['Global_Sales'].plot()
# Out:
# <AxesSubplot:>

# %%
column = 'Global_Sales'

df = pd.pivot_table(df, values=column, index=["Year_of_Release"], columns=["Platform"])
df
# Out:
# Platform             2600   3DO       3DS        DC        DS        GB  \
# Year_of_Release
# 1980.0           1.264444   NaN       NaN       NaN       NaN       NaN
# 1981.0           0.777609   NaN       NaN       NaN       NaN       NaN
# 1982.0           0.801667   NaN       NaN       NaN       NaN       NaN
# 1983.0           0.530000   NaN       NaN       NaN       NaN       NaN
# 1984.0           0.270000   NaN       NaN       NaN       NaN       NaN
# 1985.0           0.450000   NaN       NaN       NaN  0.020000       NaN
# 1986.0           0.330000   NaN       NaN       NaN       NaN       NaN
# 1987.0           0.330000   NaN       NaN       NaN       NaN       NaN
# 1988.0           0.375000   NaN       NaN       NaN       NaN  1.430000
# 1989.0           0.310000   NaN       NaN       NaN       NaN  6.498000
# 1990.0                NaN   NaN       NaN       NaN       NaN  1.630000
# 1991.0                NaN   NaN       NaN       NaN       NaN  0.618889
# ...

# %%
df.groupby['Global_Release'].mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/_s/m1lvmlq110j9tmmdnxjfw47h0000gn/T/ipykernel_22291/1078921173.py in <module>
# ----> 1 df.groupby['Global_Release'].mean()
#
# TypeError: 'method' object is not subscriptable
